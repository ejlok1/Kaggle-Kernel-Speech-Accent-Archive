# %% [markdown]
# # Part 2 - Extracting Audio Features
#
# Eu Jin Lok
# <br>Kernel post for __[Speech Accent Archive](https://www.kaggle.com/rtatman/speech-accent-archive)__ on Kaggle
# <br>20 January 2019
#
#
# # Understand the various features we can extract from audio, and use it to predict gender and accents
#
#
# In part 2 of this series, I'll introduce the various types of features from audio and we can see how these features differ when we compare between genders and accent types. I'm hoping one of these features will be distinctive enough that we could use it for predictive modelling in the next part. Fingers cross!
#
# I would also like to acknowledge 2 people whom I've learnt alot from:
# - __[Jayesh Saita](https://towardsdatascience.com/ok-google-how-to-do-speech-recognition-f77b5d7cbe0b)__, whose blog I really liked and helped me understand audio features and MFCCs in the early stages of my journey
# - __[Zafarullah Mahmood](https://www.kaggle.com/fizzbuzz/beginner-s-guide-to-audio-data)__, whose Kaggle Kernel basically became the canvas for all audio work that I do at work and outside work. Please do check out his kernels whom I've drawn lots of inspiration from!
#
# This part 2 kernel will cover a few items so I'll provide a brief agenda:
# - Core concepts in Audio
# - Time domain features
#     - Audio wave
# - Frequency domain features
#     - MFCC
#     - Log Mel-spectogram
#     - Harmonic-percussive source separation
#     - Chroma
#
# Again, thanks to the awesome Kaggle community, and the broader data science community. Without further ado, lets begin!

# %%
import pandas as pd       
import os 
import math 
import numpy as np
import matplotlib.pyplot as plt  
import IPython.display as ipd  # To play sound in the notebook
import librosa
import librosa.display
#os.chdir(".../input")
os.chdir("C:\\Users\\User\\Documents\\GIT\\Kaggle-Kernel-Speech-Accent-Archive\\")

# %% [markdown]
# ------------------------------
# After loading the files and setting our directory path, we're going to use the two Kentucky accent speakers that we heard from __[Part 1](https://www.kaggle.com/ejlok1/part-1-data-exploration-deep-learning-series)__. Here's another quick replay of how they sound if you've forgotten:

# %%
# Play female from Kentucky
fname_f = 'recordings\\' + 'english385.mp3'   
ipd.Audio(fname_f)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Play male from Kentucky
fname_m = 'recordings\\' + 'english381.mp3'
ipd.Audio(fname_m)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Core concepts in Audio

# %% [markdown]
# The first few concept I'm going to introduce is
# - Amplitude
# - Time
# - sampling rate
# - duration
# -
#
# Amplitude is the . The most intuitve plot is a Time by amplitude plot. Its what we learn. However, its not the only way to represent the data or used as feature. Another equally good way of doing this is to look at it by the frequency domain.
#
# Its alot to take in, I know. But a great anology is to think of pictures. Like pictures, you have a full resolution of xxxx by xxxx which you can down sample to xxxx. This down sampling is analogous to a audio sampling rate. A full sampling rate is 44k but, you don't always need to have it in this' High Fidelity'. A common sampling rate is....xxxx 22k.
#
# So what we're going to do is use the same audio file but plot the 2 different sampling rates to see how they differ, one at full 44100 and the other at 6000. I won't go into detail explaining the 44k sampling rate in the interest of keeping this notebook short etc etc but I'll point you to etc etc
#
# We're also going to chop up the audio duration to just 5 seconds so we can zoom in. That way we can see the difference by zooming in. Otherwise they wouldn't be obvious enough to notice the difference (Another reason why you don't need to sample the entire audio)

# %% [markdown]
# ![Audio%20wave.png](attachment:Audio%20wave.png)
# The time vs frequency view point or domain sourced from __[here](https://docs.google.com/presentation/d/1zzgNu_HbKL2iPkHS8-qhtDV20QfWt9lC3ZwPVZo8Rw0/pub?start=false&loop=false&delayms=3000&slide=id.g5a7a9806e_0_84)__

# %% [markdown]
# ## 1. Audio wave
#
# This is of course the first most common form of the data, and is the only time domain feature that I am aware off. lets use this opporunity to plot the two audio files again at their most native audio format which is the wave form. We're also going to down sample them and chop the audio file at 5 seconds just so its easier to visualise the difference.

# %%
# The full 'high fidelity' sampling rate of 44k 
SAMPLE_RATE = 44100
fname_f = 'recordings\\' + 'english385.mp3' 
y, sr = librosa.load(fname_f, sr=SAMPLE_RATE, duration = 5)

plt.figure(figsize=(12, 3))
plt.figure()
librosa.display.waveplot(y, sr=sr)
plt.title('Audio sampled at 44100 hrz')
# Out:
# Text(0.5,1,'Audio sampled at 44100 hrz')

# %%
# The 'low fidelity' sampling rate of 6k 
SAMPLE_RATE = 6000
fname_f = 'recordings\\' + 'english385.mp3' 
y, sr = librosa.load(fname_f, sr=SAMPLE_RATE, duration = 5)

plt.figure(figsize=(12, 3))
plt.figure()
librosa.display.waveplot(y, sr=sr)
plt.title('Audio sampled at 6000 hrz')
# Out:
# Text(0.5,1,'Audio sampled at 6000 hrz')

# %%
# The very 'low fidelity' sampling rate of 1k 
SAMPLE_RATE = 1000
fname_f = 'recordings\\' + 'english385.mp3' 
y, sr = librosa.core.load(fname_f, sr=SAMPLE_RATE, duration = 5)

plt.figure(figsize=(12, 3))
plt.figure()
librosa.display.waveplot(y, sr=sr)
plt.title('Audio sampled at 1000 hrz')
# Out:
# Text(0.5,1,'Audio sampled at 1000 hrz')

# %% [markdown]
# Note the minor differences between the 441000 and the 6000? Generally 21500 sampling rate is the most common one people use. It's close enough to being an audible audio. Much like shrinking a picture from 2000 x 2000 to 1000  x 1000. But once you go down to sampling rate at 1000 hrz, it starts to become more blurry. So moving foward we're going to use a sampling rate of 21500 hrz to be safe, and comparing the male and female speakers from Kentucky
#
# Lets hear the male version... at 6000 hrz and chopped at 5 seconds. You can see has some distinctive pattern over the female equivalent

# %%
# The full 'high fidelity' sampling rate of 6k 
SAMPLE_RATE = 6000
fname_m = 'recordings\\' + 'english381.mp3' 
y, sr = librosa.load(fname_m, sr=SAMPLE_RATE, duration = 5)

plt.figure(figsize=(12, 3))
plt.figure()
librosa.display.waveplot(y, sr=sr)
plt.title('Audio sampled at 6000 hrz')
# Out:
# Text(0.5,1,'Audio sampled at 6000 hrz')

# %% [markdown]
# ## 2. MFCC
# First feature of the rank is MFCC (link). MFCC is a sentence... Ok so we're now going to explore MFCC and comparing males and female voices

# %%
# MFCC for female 
SAMPLE_RATE = 21500
fname_f = 'recordings\\' + 'english385.mp3'  
y, sr = librosa.load(fname_f, sr=SAMPLE_RATE, duration = 5) # Chop audio at 5 secs... 
mfcc = librosa.feature.mfcc(y=y, sr=SAMPLE_RATE, n_mfcc = 5) # 5 MFCC components

plt.figure(figsize=(12, 6))
plt.subplot(3,1,1)
librosa.display.specshow(mfcc)
plt.ylabel('MFCC')
plt.colorbar()

# %%
# MFCC for male  
SAMPLE_RATE = 21500
fname_m = 'recordings\\' + 'english381.mp3'  
y, sr = librosa.load(fname_m, sr=SAMPLE_RATE, duration = 5)
mfcc = librosa.feature.mfcc(y=y, sr=SAMPLE_RATE, n_mfcc = 5)

plt.figure(figsize=(12, 6))
plt.subplot(3,1,1)
librosa.display.specshow(mfcc)
plt.ylabel('MFCC')
plt.colorbar()

# %% [markdown]
# Notice the difference? Seems like there could be something here.
#
# Generally in practice one would use the entire duration of the audio and set a higher number of MFCC components, usually between 20 and 40. But i used 5 secs and 5 MFCC components just so its easier to visualise the difference. We will use the optimal settings later in the actual modelling component

# %% [markdown]
# ## 3. Log Mel-spectogram
#
# Log of the Mel-spectogram. This is

# %%
# Log Mel-spectogram for female 
SAMPLE_RATE = 21500
fname_f = 'recordings\\' + 'english385.mp3'  
y, sr = librosa.load(fname_f, sr=SAMPLE_RATE, duration = 5) # Chop audio at 5 secs... 
melspec = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)

# Convert to log scale (dB). We'll use the peak power (max) as reference.
log_S = librosa.amplitude_to_db(melspec)

# Display the log mel spectrogram
plt.figure(figsize=(12,4))
librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')
plt.title('Log mel spectrogram')
plt.colorbar(format='%+02.0f dB')
plt.tight_layout()

# %%
# Log Mel-spectogram for male 
SAMPLE_RATE = 21500
fname_m = 'recordings\\' + 'english381.mp3'  
y, sr = librosa.load(fname_m, sr=SAMPLE_RATE, duration = 5) # Chop audio at 5 secs... 
melspec = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)

# Convert to log scale (dB). We'll use the peak power (max) as reference.
log_S = librosa.amplitude_to_db(melspec)

# Display the log mel spectrogram
plt.figure(figsize=(12,4))
librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')
plt.title('Log mel spectrogram')
plt.colorbar(format='%+02.0f dB')
plt.tight_layout()

# %% [markdown]
# I've also heard about a Mel Power spectogram thou I haven't had any experience using it, hence I really can't comment how good it is compared to a Log Mel spectogram. Perhaps someone else who's a real expert can elaborate further. Leave the comments down below!

# %% [markdown]
# ## 4. Harmonic-percussive source separation
#
# Its a mouthful to pronounce, but essentially it is quite literal in what it means. This feature seperates the harmonic and the percussive source of an audio file.
#
# There's a really good notebook that explains how this works https://musicinformationretrieval.com/hpss.html

# %%
SAMPLE_RATE = 21500
fname_f = 'recordings\\' + 'english385.mp3'  
y, sr = librosa.load(fname_f, sr=SAMPLE_RATE, duration = 5) 
y_harmonic, y_percussive = librosa.effects.hpss(y)

ipd.Audio(y_harmonic, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(y_percussive, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# harmonic 
melspec = librosa.feature.melspectrogram(y_harmonic, sr=sr, n_mels=128)
log_h = librosa.amplitude_to_db(melspec)

# percussive
melspec = librosa.feature.melspectrogram(y_percussive, sr=sr, n_mels=128)
log_p = librosa.amplitude_to_db(melspec)

# Display the log mel spectrogram of both harmonic and percussive
plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
librosa.display.specshow(log_h, sr=sr, x_axis='time', y_axis='mel')
plt.title('Log mel spectrogram for female harmonic')
plt.colorbar(format='%+02.0f dB')

plt.subplot(2,1,2)
librosa.display.specshow(log_p, sr=sr, x_axis='time', y_axis='mel')
plt.title('Log mel spectrogram for female percussive')
plt.colorbar(format='%+02.0f dB')

# %%
# Here's another alternative way to go about getting HPSS which is the decompose route. Output's the same but just a shortcut
# Lets use this one for the male 
SAMPLE_RATE = 21500
fname_f = 'recordings\\' + 'english381.mp3'  
y, sr = librosa.load(fname_f, sr=SAMPLE_RATE, duration = 5)
X = librosa.stft(y)
H, P = librosa.decompose.hpss(X)  # Both Harmonic and Percussive as spectogram 
Hmag = librosa.amplitude_to_db(H) # Get log mel-spectogram 
Pmag = librosa.amplitude_to_db(P)

# Have a listen to male harmonic 
h = librosa.istft(H)
ipd.Audio(h, rate=SAMPLE_RATE)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\librosa\core\spectrum.py:958: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(magphase(D)[0]) instead.
#   warnings.warn('amplitude_to_db was called on complex input so phase '
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Have a listen to male percussive 
p = librosa.istft(P)
ipd.Audio(p, rate=SAMPLE_RATE)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Display the log mel spectrogram of both harmonic and percussive
plt.figure(figsize=(12,6))

plt.subplot(2,1,1)
librosa.display.specshow(Hmag, sr=sr, x_axis='time', y_axis='mel')
plt.title('Log mel spectrogram for male harmonic')
plt.colorbar(format='%+02.0f dB')

plt.subplot(2,1,2)
librosa.display.specshow(Pmag, sr=sr, x_axis='time', y_axis='mel')
plt.title('Log mel spectrogram for male percussive')
plt.colorbar(format='%+02.0f dB')

# %% [markdown]
# ## 5. Chroma
#
# This feature is still pretty new to me. But the way I understand it is ....
#
# Again, this web is awesome https://musicinformationretrieval.com/chroma.html

# %%
SAMPLE_RATE = 21500
fname_f = 'recordings\\' + 'english381.mp3'  
y, sr = librosa.load(fname_f, sr=SAMPLE_RATE, duration = 5)
C = librosa.feature.chroma_cqt(y=y, sr=sr)

# Make a new figure
plt.figure(figsize=(12,4))

# Display the chromagram: the energy in each chromatic pitch class as a function of time
# To make sure that the colors span the full range of chroma values, set vmin and vmax
librosa.display.specshow(C, sr=sr, x_axis='time', y_axis='chroma', vmin=0, vmax=1)

plt.title('Chromagram')
plt.colorbar()

plt.tight_layout()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\librosa\util\utils.py:1005: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return (x > x_pad[inds1]) & (x >= x_pad[inds2])

# %%
SAMPLE_RATE = 21500
fname_f = 'recordings\\' + 'english385.mp3'  
y, sr = librosa.load(fname_f, sr=SAMPLE_RATE, duration = 5)
C = librosa.feature.chroma_cqt(y=y, sr=sr)

# Make a new figure
plt.figure(figsize=(12,4))

# Display the chromagram: the energy in each chromatic pitch class as a function of time
# To make sure that the colors span the full range of chroma values, set vmin and vmax
librosa.display.specshow(C, sr=sr, x_axis='time', y_axis='chroma', vmin=0, vmax=1)

plt.title('Chromagram')
plt.colorbar()

plt.tight_layout()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\librosa\util\utils.py:1005: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return (x > x_pad[inds1]) & (x >= x_pad[inds2])

# %% [markdown]
# ------------------------------
# And there you have it! The 5 features you can extract from audio. Note that there are more features you can extract such as Beat Tracking, etc etc. But I'm not familiar with them. So I won't cover them as I don't want to risk mis-informing other users. I'll let the experts elaborate on those other features.
#
# So moving on, part 3 we will go into the actual modelling. First up, I will show how you could use the traditional machine learning models first such as Gradient Boosting and Random Forest, before jumping into deep learning. Then at Part 4 we'll go into Deep Learning.
#
# Stay Tuned!
